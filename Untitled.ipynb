# %%
import pandas as pd
shark_csv_folder = pd.read_csv("OUTPUT/v2_GSAF5.csv",encoding='latin1')
shark_csv_folder.head()
# Out:
#    Unnamed: 0   Case Number       Date  Year        Type    Country      Area  \
# 0           0  2016.09.18.c  18-Sep-16  2016  Unprovoked        USA   Florida
# 1           1  2016.09.18.b  18-Sep-16  2016  Unprovoked        USA   Florida
# 2           2  2016.09.18.a  18-Sep-16  2016  Unprovoked        USA   Florida
# 3           3    2016.09.17  17-Sep-16  2016  Unprovoked  AUSTRALIA  Victoria
# 4           4    2016.09.15  16-Sep-16  2016  Unprovoked  AUSTRALIA  Victoria
#
#                            Location Activity             Name  ...  \
# 0  New Smyrna Beach, Volusia County  Surfing             male  ...
# 1  New Smyrna Beach, Volusia County  Surfing   Chucky Luciano  ...
# 2  New Smyrna Beach, Volusia County  Surfing             male  ...
# 3                  Thirteenth Beach  Surfing  Rory Angiolella  ...
# 4                       Bells Beach  Surfing             male  ...
#
#   Fatal (Y/N)   Time   Species        Investigator or Source  \
# ...

# %%
for i in range(len(shark_csv_folder)):
    dicc1={'NEW BRITAIN':'PAPUA NEW GUINEA',
           'ENGLAND':'UNITED KINGDOM', 
           'SCOTLAND':'UNITED KINGDOM',
           'WESTERN SAMOA':'SAMOA',
           'ST. MAARTIN':'SAINT MARTIN', 
           'ST. MARTIN':'SAINT MARTIN',
           'ST. HELENA':'SAINT HELENA',
           'ST HELENA':'SAINT HELENA'
          }
    
    for x,y in dicc1.items(): 
            shark_csv_folder['Country'].values[i] = shark_csv_folder['Country'].values[i].replace(x, y)

shark_csv_folder['Country']
# Out:
# 0             USA
# 1             USA
# 2             USA
# 3       AUSTRALIA
# 4       AUSTRALIA
#           ...
# 5987    AUSTRALIA
# 5988    AUSTRALIA
# 5989          USA
# 5990       PANAMA
# 5991    SRI LANKA
# Name: Country, Length: 5992, dtype: object

# %%
shark_csv_folder['Country'].value_counts()
# Out:
# USA                         2116
# AUSTRALIA                   1279
# SOUTH AFRICA                 565
# OUT OF SCOPE                 155
# PAPUA NEW GUINEA             153
#                             ...
# SLOVENIA                       1
# NORTHERN MARIANA ISLANDS       1
# GUYANA                         1
# MAYOTTE                        1
# COOK ISLANDS                   1
# Name: Country, Length: 142, dtype: int64
