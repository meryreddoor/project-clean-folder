# %%
import pandas as pd
import numpy as np
import re

# %%
hdi = pd.read_csv("OUTPUT/Human Development Index (HDI).csv",encoding='latin1')
hdi.head()
# Out:
#   Human Development Index (HDI)   Unnamed: 1 Unnamed: 2  Unnamed: 3  \
# 0               HDI Rank (2018)      Country       1990         NaN
# 1                             1       Norway       0.85         NaN
# 2                             2  Switzerland      0.832         NaN
# 3                             3      Ireland      0.764         NaN
# 4                             4      Germany      0.801         NaN
#
#   Unnamed: 4  Unnamed: 5 Unnamed: 6  Unnamed: 7 Unnamed: 8  Unnamed: 9  ...  \
# 0       1991         NaN       1992         NaN       1993         NaN  ...
# 1      0.856         NaN      0.862         NaN       0.87         NaN  ...
# 2      0.834         NaN      0.836         NaN      0.841         NaN  ...
# 3      0.767         NaN      0.772         NaN      0.781         NaN  ...
# 4      0.809         NaN      0.814         NaN      0.824         NaN  ...
#
#   Unnamed: 49  Unnamed: 50 Unnamed: 51  Unnamed: 52 Unnamed: 53  Unnamed: 54  \
# 0         NaN         2014         NaN         2015         NaN         2016
# 1         NaN        0.945         NaN        0.948         NaN        0.951
# 2         NaN        0.939         NaN        0.943         NaN        0.943
# 3         NaN         0.92         NaN        0.926         NaN        0.936
# 4         NaN         0.93         NaN        0.933         NaN        0.936
#
#   Unnamed: 55  Unnamed: 56 Unnamed: 57  Unnamed: 58
# 0         NaN         2017         NaN         2018
# 1         NaN        0.953         NaN        0.954
# 2         NaN        0.943         NaN        0.946
# 3         NaN        0.939         NaN        0.942
# 4         NaN        0.938         NaN        0.939
#
# [5 rows x 59 columns]

# %%
#Deleting first row.
hdi.columns = hdi.iloc[0]
hdi = hdi.reindex(hdi.index.drop(0)).reset_index(drop=True)
hdi.columns.name = None
hdi
# Out:
#     HDI Rank (2018)                                            Country   1990  \
# 0                 1                                             Norway   0.85
# 1                 2                                        Switzerland  0.832
# 2                 3                                            Ireland  0.764
# 3                 4                                            Germany  0.801
# 4                 4                             Hong Kong, China (SAR)  0.781
# ..              ...                                                ...    ...
# 201                                     Small Island Developing States  0.595
# 202                  Organization for Economic Co-operation and Dev...  0.785
# 203                                                              World  0.598
# 204             NaN                                  Human Development
# 205             NaN                                            Regions
#
#     NaN   1991 NaN   1992 NaN   1993 NaN  ... NaN   2014 NaN   2015 NaN  \
# 0   NaN  0.856 NaN  0.862 NaN   0.87 NaN  ... NaN  0.945 NaN  0.948 NaN
# 1   NaN  0.834 NaN  0.836 NaN  0.841 NaN  ... NaN  0.939 NaN  0.943 NaN
# 2   NaN  0.767 NaN  0.772 NaN  0.781 NaN  ... NaN   0.92 NaN  0.926 NaN
# 3   NaN  0.809 NaN  0.814 NaN  0.824 NaN  ... NaN   0.93 NaN  0.933 NaN
# 4   NaN  0.786 NaN  0.791 NaN  0.799 NaN  ... NaN  0.924 NaN  0.927 NaN
# ..   ..    ...  ..    ...  ..    ...  ..  ...  ..    ...  ..    ...  ..
# 201 NaN  0.598 NaN  0.603 NaN  0.608 NaN  ... NaN  0.712 NaN  0.717 NaN
# 202 NaN   0.79 NaN  0.788 NaN    0.8 NaN  ... NaN  0.886 NaN  0.889 NaN
# 203 NaN  0.601 NaN  0.601 NaN  0.608 NaN  ... NaN  0.718 NaN  0.722 NaN
# 204 NaN     .. NaN     .. NaN     .. NaN  ... NaN     .. NaN     .. NaN
# 205 NaN     .. NaN     .. NaN     .. NaN  ... NaN     .. NaN     .. NaN
#
#       2016 NaN   2017 NaN   2018
# 0    0.951 NaN  0.953 NaN  0.954
# 1    0.943 NaN  0.943 NaN  0.946
# 2    0.936 NaN  0.939 NaN  0.942
# 3    0.936 NaN  0.938 NaN  0.939
# 4    0.931 NaN  0.937 NaN  0.939
# ..     ...  ..    ...  ..    ...
# 201  0.719 NaN  0.722 NaN  0.723
# 202  0.892 NaN  0.894 NaN  0.895
# 203  0.727 NaN  0.729 NaN  0.731
# 204     .. NaN     .. NaN     ..
# 205     .. NaN     .. NaN     ..
#
# [206 rows x 59 columns]

# %%
hdi.columns=['Index','Country','Year 1990','NA1','Year 1991','NA2','Year 1992','NA3','Year 1993','NA4','Year 1994','NA5','Year 1995','NA6','Year 1996','NA7','Year 1997','NA8','Year 1998','NA9','Year 1999','NA10','Year 2000','NA11','Year 2001','NA12','Year 2002','NA13','Year 2003','NA14','Year 2004','NA15','Year 2005','NA16','Year 2006','NA17','Year 2007','NA18','Year 2008','NA19','Year 2009','NA20','Year 2010','NA21','Year 2011','NA22','Year 2012','NA23','Year 2013','NA24','Year 2014','NA25','Year 2015','NA26','Year 2016','NA27','Year 2017','NA28','Year 2018']
hdi
# Out:
#     Index                                            Country Year 1990  NA1  \
# 0       1                                             Norway      0.85  NaN
# 1       2                                        Switzerland     0.832  NaN
# 2       3                                            Ireland     0.764  NaN
# 3       4                                            Germany     0.801  NaN
# 4       4                             Hong Kong, China (SAR)     0.781  NaN
# ..    ...                                                ...       ...  ...
# 201                           Small Island Developing States     0.595  NaN
# 202        Organization for Economic Co-operation and Dev...     0.785  NaN
# 203                                                    World     0.598  NaN
# 204   NaN                                  Human Development            NaN
# 205   NaN                                            Regions            NaN
#
#     Year 1991  NA2 Year 1992  NA3 Year 1993  NA4  ... NA24  Year 2014 NA25  \
# 0       0.856  NaN     0.862  NaN      0.87  NaN  ...  NaN      0.945  NaN
# 1       0.834  NaN     0.836  NaN     0.841  NaN  ...  NaN      0.939  NaN
# 2       0.767  NaN     0.772  NaN     0.781  NaN  ...  NaN       0.92  NaN
# 3       0.809  NaN     0.814  NaN     0.824  NaN  ...  NaN       0.93  NaN
# 4       0.786  NaN     0.791  NaN     0.799  NaN  ...  NaN      0.924  NaN
# ..        ...  ...       ...  ...       ...  ...  ...  ...        ...  ...
# 201     0.598  NaN     0.603  NaN     0.608  NaN  ...  NaN      0.712  NaN
# 202      0.79  NaN     0.788  NaN       0.8  NaN  ...  NaN      0.886  NaN
# 203     0.601  NaN     0.601  NaN     0.608  NaN  ...  NaN      0.718  NaN
# 204        ..  NaN        ..  NaN        ..  NaN  ...  NaN         ..  NaN
# 205        ..  NaN        ..  NaN        ..  NaN  ...  NaN         ..  NaN
#
#      Year 2015 NA26  Year 2016 NA27  Year 2017 NA28  Year 2018
# 0        0.948  NaN      0.951  NaN      0.953  NaN      0.954
# 1        0.943  NaN      0.943  NaN      0.943  NaN      0.946
# 2        0.926  NaN      0.936  NaN      0.939  NaN      0.942
# 3        0.933  NaN      0.936  NaN      0.938  NaN      0.939
# 4        0.927  NaN      0.931  NaN      0.937  NaN      0.939
# ..         ...  ...        ...  ...        ...  ...        ...
# 201      0.717  NaN      0.719  NaN      0.722  NaN      0.723
# 202      0.889  NaN      0.892  NaN      0.894  NaN      0.895
# 203      0.722  NaN      0.727  NaN      0.729  NaN      0.731
# 204         ..  NaN         ..  NaN         ..  NaN         ..
# 205         ..  NaN         ..  NaN         ..  NaN         ..
#
# [206 rows x 59 columns]

# %%
hdi['Country'] = hdi['Country'].str.upper()

# %%
hdi[['Country','Year 2018']]
# Out:
#                                                Country Year 2018
# 0                                               NORWAY     0.954
# 1                                          SWITZERLAND     0.946
# 2                                              IRELAND     0.942
# 3                                              GERMANY     0.939
# 4                               HONG KONG, CHINA (SAR)     0.939
# ..                                                 ...       ...
# 201                     SMALL ISLAND DEVELOPING STATES     0.723
# 202  ORGANIZATION FOR ECONOMIC CO-OPERATION AND DEV...     0.895
# 203                                              WORLD     0.731
# 204                                  HUMAN DEVELOPMENT        ..
# 205                                            REGIONS        ..
#
# [206 rows x 2 columns]

# %%
for e in hdi:
    if e!='Year 2018' and e!='Country':
        hdi=hdi.drop([e],axis=1)
    else:
        pass
hdi
# Out:
#                                                Country Year 2018
# 0                                               NORWAY     0.954
# 1                                          SWITZERLAND     0.946
# 2                                              IRELAND     0.942
# 3                                              GERMANY     0.939
# 4                               HONG KONG, CHINA (SAR)     0.939
# ..                                                 ...       ...
# 201                     SMALL ISLAND DEVELOPING STATES     0.723
# 202  ORGANIZATION FOR ECONOMIC CO-OPERATION AND DEV...     0.895
# 203                                              WORLD     0.731
# 204                                  HUMAN DEVELOPMENT        ..
# 205                                            REGIONS        ..
#
# [206 rows x 2 columns]

# %%
hdi['Country']=hdi['Country'].str.replace(r"(.*)?HONG KONG(.*)?",'HONG KONG')
hdi['Country']=hdi['Country'].str.replace(r"(.*)?RUSSIA(.*)?",'RUSSIA')
hdi['Country']=hdi['Country'].str.replace(r"(.*)?CHINA(.*)?",'CHINA')
hdi['Country']=hdi['Country'].str.replace(r"(.*)?BOLIVIA(.*)?",'BOLIVIA')
hdi['Country']=hdi['Country'].str.replace(r"(.*)?CONGO(.*)?",'CONGO')
hdi['Country']=hdi['Country'].str.replace(r"(.*)?ESWATINI(.*)?",'ESWATINI')
hdi['Country']=hdi['Country'].str.replace(r"(.*)?IRAN(.*)?",'IRAN')
hdi['Country']=hdi['Country'].str.replace(r"(.*)?MICRONESIA(.*)?",'MICRONESIA')
hdi['Country']=hdi['Country'].str.replace(r"(.*)?MOLDOVA(.*)?",'MOLDOVA')
hdi['Country']=hdi['Country'].str.replace(r"(.*)?TANZANIA(.*)?",'TANZANIA')
hdi['Country']=hdi['Country'].str.replace(r"(.*)?VENEZUELA(.*)?",'VENEZUELA')

# %% [markdown]
# 1-(“High Human Development”), with more than 0,80
#
# 2-(“Medium Human Development”), from 0,50 to 0,80
#
# 3-(“Low Human Development”), with less than 0,55

# %%
Human_Development = []

for x in hdi['Year 2018']:
    
    if x > '0.8':
        Human_Development.append('High Human Development')
    elif '0.8' >= x >= '0.5':
        Human_Development.append('Medium Human Development')
    else:
        Human_Development.append('Low Human Development')


hdi['Human_Development'] = Human_Development

# %%
hdi
# Out:
#                                                Country Year 2018  \
# 0                                               NORWAY     0.954
# 1                                          SWITZERLAND     0.946
# 2                                              IRELAND     0.942
# 3                                              GERMANY     0.939
# 4                                            HONG KONG     0.939
# ..                                                 ...       ...
# 201                     SMALL ISLAND DEVELOPING STATES     0.723
# 202  ORGANIZATION FOR ECONOMIC CO-OPERATION AND DEV...     0.895
# 203                                              WORLD     0.731
# 204                                  HUMAN DEVELOPMENT        ..
# 205                                            REGIONS        ..
#
#             Human_Development
# 0      High Human Development
# 1      High Human Development
# 2      High Human Development
# 3      High Human Development
# 4      High Human Development
# ..                        ...
# 201  Medium Human Development
# 202    High Human Development
# 203  Medium Human Development
# 204     Low Human Development
# 205     Low Human Development
#
# [206 rows x 3 columns]

# %%
High=hdi[hdi['Human_Development'].eq('High Human Development')]
High
# Out:
#                                                Country Year 2018  \
# 0                                               NORWAY     0.954
# 1                                          SWITZERLAND     0.946
# 2                                              IRELAND     0.942
# 3                                              GERMANY     0.939
# 4                                            HONG KONG     0.939
# ..                                                 ...       ...
# 59                                             BAHAMAS     0.805
# 60                                            MALAYSIA     0.804
# 61                                          SEYCHELLES     0.801
# 189                        VERY HIGH HUMAN DEVELOPMENT     0.892
# 202  ORGANIZATION FOR ECONOMIC CO-OPERATION AND DEV...     0.895
#
#           Human_Development
# 0    High Human Development
# 1    High Human Development
# 2    High Human Development
# 3    High Human Development
# 4    High Human Development
# ..                      ...
# 59   High Human Development
# 60   High Human Development
# 61   High Human Development
# 189  High Human Development
# 202  High Human Development
#
# [64 rows x 3 columns]

# %%
#We have selected the TOP10 of Developed Countries.
top10=High.head(10)
top10
# Out:
#        Country Year 2018       Human_Development
# 0       NORWAY     0.954  High Human Development
# 1  SWITZERLAND     0.946  High Human Development
# 2      IRELAND     0.942  High Human Development
# 3      GERMANY     0.939  High Human Development
# 4    HONG KONG     0.939  High Human Development
# 5    AUSTRALIA     0.938  High Human Development
# 6      ICELAND     0.938  High Human Development
# 7       SWEDEN     0.937  High Human Development
# 8    SINGAPORE     0.935  High Human Development
# 9  NETHERLANDS     0.934  High Human Development
